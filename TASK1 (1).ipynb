# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = {
    'Age': [18, 21, 22, 25, 30, 28, 35, 40, 23, 27, 29, 33, 31, 26, 24, 19, 45, 50, 55, 60],
    'Gender': ['Male', 'Female', 'Male', 'Male', 'Female', 'Female',
               'Male', 'Female', 'Male', 'Male', 'Female', 'Female',
               'Male', 'Male', 'Female', 'Female', 'Male', 'Female',
               'Male', 'Female']
}
df = pd.DataFrame(data)


plt.figure(figsize=(8,5))
sns.histplot(df['Age'], bins=8, kde=True, color='skyblue')
plt.title("Age Distribution in Population")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.show()


plt.figure(figsize=(6,4))
sns.countplot(x='Gender', data=df, palette="Set2")
plt.title("Gender Distribution in Population")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
# Out:
# Matplotlib is building the font cache; this may take a moment.
# C:\Users\naman\AppData\Local\Temp\ipykernel_8324\3403985021.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Gender', data=df, palette="Set2")
